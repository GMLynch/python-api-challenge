# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#API url
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperials"

#set the counters
city_counter = 0
set_counter = 1

# set up df to hold reponse info
weather_df = pd.DataFrame({'City': cities})
weather_df['Lat'] = "" 
weather_df['Lng'] = ""
weather_df['Country'] = ""
weather_df['Date'] = "" 
weather_df['Max Temp'] = ""
weather_df['Humidity'] = ""
weather_df['Cloudiness'] = ""
weather_df['Windspeed'] = ""


print("Beginning Data Retrieval")
print(f"--------------------------")


# Loop through the list of cities and perform a request for data on each

for index, row in weather_df.iterrows(): 
    city = row["City"]
    query_url = url +"appid" + weather_api_key +"&q=" + city
    
    response = requests.get(query_url).json() 
    
    try:
        print(f"Processing Record {city_counter} of Set {set_counter}|{city}")  
        weather_df.loc[index, 'Cloudiness'] = response['clouds']['all']
        weather_df.loc[index, 'Country'] = response['sys']['country']
        weather_df.loc[index, 'Date'] = response['dt']
        weather_df.loc[index, 'Humidity'] = response['main']['humidity']
        weather_df.loc[index, 'Lat'] = response['coord']['lat']
        weather_df.loc[index, 'Lng'] = response['coord']['lon']
        weather_df.loc[index, 'Max Temp'] = response['main']['temp_max']
        weather_df.loc[index, 'Windspeed'] = response['wind']['speed']
        
        
        
                   
    except (KeyError):
        print("City not found. Skipping")
     #Increase the record count
        city_counter += 1
            
    if city_counter == 51:
        set_counter += 1
        city_counter = 0

print("Data Retrieval Complete")
# Out:
# Beginning Data Retrieval
# --------------------------
# Processing Record 0 of Set 1|kodiak
# City not found. Skipping
# Processing Record 1 of Set 1|kapaa
# City not found. Skipping
# Processing Record 2 of Set 1|ushuaia
# City not found. Skipping
# Processing Record 3 of Set 1|busselton
# City not found. Skipping
# Processing Record 4 of Set 1|vaini
# City not found. Skipping
# Processing Record 5 of Set 1|tuktoyaktuk
# City not found. Skipping
# Processing Record 6 of Set 1|kapoeta
# City not found. Skipping
# Processing Record 7 of Set 1|mataura
# City not found. Skipping
# Processing Record 8 of Set 1|port alfred
# City not found. Skipping
# Processing Record 9 of Set 1|dali
# City not found. Skipping
# Processing Record 10 of Set 1|necochea
# City not found. Skipping
# Processing Record 11 of Set 1|yokadouma
# City not found. Skipping
# Processing Record 12 of Set 1|katsuura
# City not found. Skipping
# Processing Record 13 of Set 1|mar del plata
# City not found. Skipping
# Processing Record 14 of Set 1|tateyama
# City not found. Skipping
# Processing Record 15 of Set 1|kruisfontein
# City not found. Skipping
# Processing Record 16 of Set 1|jamestown
# City not found. Skipping
# Processing Record 17 of Set 1|castro
# City not found. Skipping
# Processing Record 18 of Set 1|vardo
# City not found. Skipping
# Processing Record 19 of Set 1|arraial do cabo
# City not found. Skipping
# Processing Record 20 of Set 1|lavrentiya
# City not found. Skipping
# Processing Record 21 of Set 1|nikolskoye
# City not found. Skipping
# Processing Record 22 of Set 1|rikitea
# City not found. Skipping
# Processing Record 23 of Set 1|san policarpo
# City not found. Skipping
# Processing Record 24 of Set 1|barentsburg
# City not found. Skipping
# Processing Record 25 of Set 1|luanda
# City not found. Skipping
# Processing Record 26 of Set 1|muros
# City not found. Skipping
# Processing Record 27 of Set 1|taltal
# City not found. Skipping
# Processing Record 28 of Set 1|mangrol
# City not found. Skipping
# Processing Record 29 of Set 1|bababe
# City not found. Skipping
# Processing Record 30 of Set 1|semnan
# City not found. Skipping
# Processing Record 31 of Set 1|hilo
# City not found. Skipping
# Processing Record 32 of Set 1|georgetown
# City not found. Skipping
# Processing Record 33 of Set 1|boa vista
# City not found. Skipping
# Processing Record 34 of Set 1|samusu
# City not found. Skipping
# Processing Record 35 of Set 1|cape town
# City not found. Skipping
# Processing Record 36 of Set 1|punta arenas
# City not found. Skipping
# Processing Record 37 of Set 1|north bend
# City not found. Skipping
# Processing Record 38 of Set 1|tilichiki
# City not found. Skipping
# Processing Record 39 of Set 1|ancud
# City not found. Skipping
# Processing Record 40 of Set 1|paris
# City not found. Skipping
# Processing Record 41 of Set 1|tasiilaq
# City not found. Skipping
# Processing Record 42 of Set 1|yellowknife
# City not found. Skipping
# Processing Record 43 of Set 1|east london
# City not found. Skipping
# Processing Record 44 of Set 1|crib point
# City not found. Skipping
# Processing Record 45 of Set 1|redlands
# City not found. Skipping
# Processing Record 46 of Set 1|rolim de moura
# City not found. Skipping
# Processing Record 47 of Set 1|chuy
# City not found. Skipping
# Processing Record 48 of Set 1|nanortalik
# City not found. Skipping
# Processing Record 49 of Set 1|ribeira grande
# City not found. Skipping
# Processing Record 50 of Set 1|havelock
# City not found. Skipping
# Processing Record 0 of Set 2|najran
# City not found. Skipping
# Processing Record 1 of Set 2|pimentel
# City not found. Skipping
# Processing Record 2 of Set 2|umzimvubu
# City not found. Skipping
# Processing Record 3 of Set 2|chokurdakh
# City not found. Skipping
# Processing Record 4 of Set 2|ishigaki
# City not found. Skipping
# Processing Record 5 of Set 2|avarua
# City not found. Skipping
# Processing Record 6 of Set 2|praia da vitoria
# City not found. Skipping
# Processing Record 7 of Set 2|houma
# City not found. Skipping
# Processing Record 8 of Set 2|portland
# City not found. Skipping
# Processing Record 9 of Set 2|tsihombe
# City not found. Skipping
# Processing Record 10 of Set 2|viedma
# City not found. Skipping
# Processing Record 11 of Set 2|sao filipe
# City not found. Skipping
# Processing Record 12 of Set 2|uniara
# City not found. Skipping
# Processing Record 13 of Set 2|hambantota
# City not found. Skipping
# Processing Record 14 of Set 2|atuona
# City not found. Skipping
# Processing Record 15 of Set 2|hithadhoo
# City not found. Skipping
# Processing Record 16 of Set 2|dingle
# City not found. Skipping
# Processing Record 17 of Set 2|mys shmidta
# City not found. Skipping
# Processing Record 18 of Set 2|longyearbyen
# City not found. Skipping
# Processing Record 19 of Set 2|puerto ayora
# City not found. Skipping
# Processing Record 20 of Set 2|mandera
# City not found. Skipping
# Processing Record 21 of Set 2|bluff
# City not found. Skipping
# Processing Record 22 of Set 2|new norfolk
# City not found. Skipping
# Processing Record 23 of Set 2|lolua
# City not found. Skipping
# Processing Record 24 of Set 2|bethel
# City not found. Skipping
# Processing Record 25 of Set 2|henties bay
# City not found. Skipping
# Processing Record 26 of Set 2|bredasdorp
# City not found. Skipping
# Processing Record 27 of Set 2|strood
# City not found. Skipping
# Processing Record 28 of Set 2|zhangye
# City not found. Skipping
# Processing Record 29 of Set 2|grand gaube
# City not found. Skipping
# Processing Record 30 of Set 2|ahipara
# City not found. Skipping
# Processing Record 31 of Set 2|hasaki
# City not found. Skipping
# Processing Record 32 of Set 2|imeni poliny osipenko
# City not found. Skipping
# Processing Record 33 of Set 2|almaznyy
# City not found. Skipping
# Processing Record 34 of Set 2|ponta do sol
# City not found. Skipping
# Processing Record 35 of Set 2|omsukchan
# City not found. Skipping
# Processing Record 36 of Set 2|talnakh
# City not found. Skipping
# Processing Record 37 of Set 2|hirara
# City not found. Skipping
# Processing Record 38 of Set 2|bambous virieux
# City not found. Skipping
# Processing Record 39 of Set 2|faanui
# City not found. Skipping
# Processing Record 40 of Set 2|carnarvon
# City not found. Skipping
# Processing Record 41 of Set 2|huarmey
# City not found. Skipping
# Processing Record 42 of Set 2|srednekolymsk
# City not found. Skipping
# Processing Record 43 of Set 2|viligili
# City not found. Skipping
# Processing Record 44 of Set 2|verkhniy landekh
# City not found. Skipping
# Processing Record 45 of Set 2|amderma
# City not found. Skipping
# Processing Record 46 of Set 2|stepnogorsk
# City not found. Skipping
# Processing Record 47 of Set 2|guerrero negro
# City not found. Skipping
# Processing Record 48 of Set 2|port elizabeth
# City not found. Skipping
# Processing Record 49 of Set 2|saryshagan
# City not found. Skipping
# Processing Record 50 of Set 2|emerald
# City not found. Skipping
# Processing Record 0 of Set 3|itarema
# City not found. Skipping
# Processing Record 1 of Set 3|soyo
# City not found. Skipping
# Processing Record 2 of Set 3|fort saint john
# City not found. Skipping
# Processing Record 3 of Set 3|dong hoi
# City not found. Skipping
# Processing Record 4 of Set 3|torbay
# City not found. Skipping
# Processing Record 5 of Set 3|sept-iles
# City not found. Skipping
# Processing Record 6 of Set 3|nouadhibou
# City not found. Skipping
# Processing Record 7 of Set 3|athens
# City not found. Skipping
# Processing Record 8 of Set 3|san patricio
# City not found. Skipping
# Processing Record 9 of Set 3|namibe
# City not found. Skipping
# Processing Record 10 of Set 3|belize
# City not found. Skipping
# Processing Record 11 of Set 3|saurimo
# City not found. Skipping
# Processing Record 12 of Set 3|terrace
# City not found. Skipping
# Processing Record 13 of Set 3|saint-philippe
# City not found. Skipping
# Processing Record 14 of Set 3|maragogi
# City not found. Skipping
# Processing Record 15 of Set 3|labrea
# City not found. Skipping
# Processing Record 16 of Set 3|aykhal
# City not found. Skipping
# Processing Record 17 of Set 3|la ronge
# City not found. Skipping
# Processing Record 18 of Set 3|hamilton
# City not found. Skipping
# Processing Record 19 of Set 3|bam
# City not found. Skipping
# Processing Record 20 of Set 3|vaitupu
# City not found. Skipping
# Processing Record 21 of Set 3|leshukonskoye
# City not found. Skipping
# Processing Record 22 of Set 3|souillac
# City not found. Skipping
# Processing Record 23 of Set 3|victoria
# City not found. Skipping
# Processing Record 24 of Set 3|khatanga
# City not found. Skipping
# Processing Record 25 of Set 3|apastovo
# City not found. Skipping
# Processing Record 26 of Set 3|hermanus
# City not found. Skipping
# Processing Record 27 of Set 3|inongo
# City not found. Skipping
# Processing Record 28 of Set 3|uwayl
# City not found. Skipping
# Processing Record 29 of Set 3|mehran
# City not found. Skipping
# Processing Record 30 of Set 3|wawa
# City not found. Skipping
# Processing Record 31 of Set 3|riyadh
# City not found. Skipping
# Processing Record 32 of Set 3|pasighat
# City not found. Skipping
# Processing Record 33 of Set 3|nizhneyansk
# City not found. Skipping
# Processing Record 34 of Set 3|albany
# City not found. Skipping
# Processing Record 35 of Set 3|marsh harbour
# City not found. Skipping
# Processing Record 36 of Set 3|kahului
# City not found. Skipping
# Processing Record 37 of Set 3|charyshskoye
# City not found. Skipping
# Processing Record 38 of Set 3|hobyo
# City not found. Skipping
# Processing Record 39 of Set 3|mogok
# City not found. Skipping
# Processing Record 40 of Set 3|aswan
# City not found. Skipping
# Processing Record 41 of Set 3|santa vitoria do palmar
# City not found. Skipping
# Processing Record 42 of Set 3|quatre cocos
# City not found. Skipping
# Processing Record 43 of Set 3|behbahan
# City not found. Skipping
# Processing Record 44 of Set 3|poum
# City not found. Skipping
# Processing Record 45 of Set 3|illoqqortoormiut
# City not found. Skipping
# Processing Record 46 of Set 3|saleaula
# City not found. Skipping
# Processing Record 47 of Set 3|qaanaaq
# City not found. Skipping
# Processing Record 48 of Set 3|bengkulu
# City not found. Skipping
# Processing Record 49 of Set 3|sorvag
# City not found. Skipping
# Processing Record 50 of Set 3|opuwo
# City not found. Skipping
# Processing Record 0 of Set 4|maceio
# City not found. Skipping
# Processing Record 1 of Set 4|barroui
# City not found. Skipping
# Processing Record 2 of Set 4|finschhafen
# City not found. Skipping
# Processing Record 3 of Set 4|pangnirtung
# City not found. Skipping
# Processing Record 4 of Set 4|butaritari
# City not found. Skipping
# Processing Record 5 of Set 4|zhigansk
# City not found. Skipping
# Processing Record 6 of Set 4|araouane
# City not found. Skipping
# Processing Record 7 of Set 4|haines junction
# City not found. Skipping
# Processing Record 8 of Set 4|were ilu
# City not found. Skipping
# Processing Record 9 of Set 4|cabo san lucas
# City not found. Skipping
# Processing Record 10 of Set 4|grand river south east
# City not found. Skipping
# Processing Record 11 of Set 4|rapid valley
# City not found. Skipping
# Processing Record 12 of Set 4|lebu
# City not found. Skipping
# Processing Record 13 of Set 4|hobart
# City not found. Skipping
# Processing Record 14 of Set 4|saldanha
# City not found. Skipping
# Processing Record 15 of Set 4|ilulissat
# City not found. Skipping
# Processing Record 16 of Set 4|upernavik
# City not found. Skipping
# Processing Record 17 of Set 4|cherskiy
# City not found. Skipping
# Processing Record 18 of Set 4|pitkyaranta
# City not found. Skipping
# Processing Record 19 of Set 4|sitka
# City not found. Skipping
# Processing Record 20 of Set 4|leh
# City not found. Skipping
# Processing Record 21 of Set 4|londoko
# City not found. Skipping
# Processing Record 22 of Set 4|beringovskiy
# City not found. Skipping
# Processing Record 23 of Set 4|louisbourg
# City not found. Skipping
# Processing Record 24 of Set 4|wadi musa
# City not found. Skipping
# Processing Record 25 of Set 4|leningradskiy
# City not found. Skipping
# Processing Record 26 of Set 4|rocha
# City not found. Skipping
# Processing Record 27 of Set 4|oksfjord
# City not found. Skipping
# Processing Record 28 of Set 4|juigalpa
# City not found. Skipping
# Processing Record 29 of Set 4|zholymbet
# City not found. Skipping
# Processing Record 30 of Set 4|isangel
# City not found. Skipping
# Processing Record 31 of Set 4|porto novo
# City not found. Skipping
# Processing Record 32 of Set 4|norman wells
# City not found. Skipping
# Processing Record 33 of Set 4|kijang
# City not found. Skipping
# Processing Record 34 of Set 4|guaruja
# City not found. Skipping
# Processing Record 35 of Set 4|kismayo
# City not found. Skipping
# Processing Record 36 of Set 4|laguna
# City not found. Skipping
# Processing Record 37 of Set 4|slavyanka
# City not found. Skipping
# Processing Record 38 of Set 4|bandarbeyla
# City not found. Skipping
# Processing Record 39 of Set 4|kaitangata
# City not found. Skipping
# Processing Record 40 of Set 4|wonogiri
# City not found. Skipping
# Processing Record 41 of Set 4|lorengau
# City not found. Skipping
# Processing Record 42 of Set 4|codrington
# City not found. Skipping
# Processing Record 43 of Set 4|fort nelson
# City not found. Skipping
# Processing Record 44 of Set 4|lompoc
# City not found. Skipping
# Processing Record 45 of Set 4|bay saint louis
# City not found. Skipping
# Processing Record 46 of Set 4|myrtle beach
# City not found. Skipping
# Processing Record 47 of Set 4|semiletka
# City not found. Skipping
# Processing Record 48 of Set 4|hervey bay
# City not found. Skipping
# Processing Record 49 of Set 4|waipawa
# City not found. Skipping
# Processing Record 50 of Set 4|belushya guba
# City not found. Skipping
# Processing Record 0 of Set 5|zaysan
# City not found. Skipping
# Processing Record 1 of Set 5|bolungarvik
# City not found. Skipping
# Processing Record 2 of Set 5|skalistyy
# City not found. Skipping
# Processing Record 3 of Set 5|north battleford
# City not found. Skipping
# Processing Record 4 of Set 5|vilyuysk
# City not found. Skipping
# Processing Record 5 of Set 5|kerema
# City not found. Skipping
# Processing Record 6 of Set 5|mutsamudu
# City not found. Skipping
# Processing Record 7 of Set 5|lata
# City not found. Skipping
# Processing Record 8 of Set 5|kalmunai
# City not found. Skipping
# Processing Record 9 of Set 5|mercedes
# City not found. Skipping
# Processing Record 10 of Set 5|saint george
# City not found. Skipping
# Processing Record 11 of Set 5|valparaiso
# City not found. Skipping
# Processing Record 12 of Set 5|abha
# City not found. Skipping
# Processing Record 13 of Set 5|puebla
# City not found. Skipping
# Processing Record 14 of Set 5|limbang
# City not found. Skipping
# Processing Record 15 of Set 5|comodoro rivadavia
# City not found. Skipping
# Processing Record 16 of Set 5|pampierstad
# City not found. Skipping
# Processing Record 17 of Set 5|jiuquan
# City not found. Skipping
# Processing Record 18 of Set 5|pevek
# City not found. Skipping
# Processing Record 19 of Set 5|yulara
# City not found. Skipping
# Processing Record 20 of Set 5|basco
# City not found. Skipping
# Processing Record 21 of Set 5|vila do maio
# City not found. Skipping
# Processing Record 22 of Set 5|baraki barak
# City not found. Skipping
# Processing Record 23 of Set 5|hettstedt
# City not found. Skipping
# Processing Record 24 of Set 5|fortuna
# City not found. Skipping
# Processing Record 25 of Set 5|kwekwe
# City not found. Skipping
# Processing Record 26 of Set 5|taolanaro
# City not found. Skipping
# Processing Record 27 of Set 5|ossora
# City not found. Skipping
# Processing Record 28 of Set 5|kidal
# City not found. Skipping
# Processing Record 29 of Set 5|mahebourg
# City not found. Skipping
# Processing Record 30 of Set 5|luderitz
# City not found. Skipping
# Processing Record 31 of Set 5|siverskiy
# City not found. Skipping
# Processing Record 32 of Set 5|montepuez
# City not found. Skipping
# Processing Record 33 of Set 5|amazar
# City not found. Skipping
# Processing Record 34 of Set 5|karratha
# City not found. Skipping
# Processing Record 35 of Set 5|erzin
# City not found. Skipping
# Processing Record 36 of Set 5|lerwick
# City not found. Skipping
# Processing Record 37 of Set 5|westerville
# City not found. Skipping
# Processing Record 38 of Set 5|komsomolskiy
# City not found. Skipping
# Processing Record 39 of Set 5|asau
# City not found. Skipping
# Processing Record 40 of Set 5|cidreira
# City not found. Skipping
# Processing Record 41 of Set 5|imeni tsyurupy
# City not found. Skipping
# Processing Record 42 of Set 5|brae
# City not found. Skipping
# Processing Record 43 of Set 5|olafsvik
# City not found. Skipping
# Processing Record 44 of Set 5|tupiza
# City not found. Skipping
# Processing Record 45 of Set 5|narsaq
# City not found. Skipping
# Processing Record 46 of Set 5|bokspits
# City not found. Skipping
# Processing Record 47 of Set 5|koumac
# City not found. Skipping
# Processing Record 48 of Set 5|skeldon
# City not found. Skipping
# Processing Record 49 of Set 5|kavaratti
# City not found. Skipping
# Processing Record 50 of Set 5|attawapiskat
# City not found. Skipping
# Processing Record 0 of Set 6|oil city
# City not found. Skipping
# Processing Record 1 of Set 6|two hills
# City not found. Skipping
# Processing Record 2 of Set 6|krasnyye baki
# City not found. Skipping
# Processing Record 3 of Set 6|galle
# City not found. Skipping
# Processing Record 4 of Set 6|airai
# City not found. Skipping
# Processing Record 5 of Set 6|mount gambier
# City not found. Skipping
# Processing Record 6 of Set 6|altay
# City not found. Skipping
# Processing Record 7 of Set 6|nantucket
# City not found. Skipping
# Processing Record 8 of Set 6|sokolo
# City not found. Skipping
# Processing Record 9 of Set 6|balimo
# City not found. Skipping
# Processing Record 10 of Set 6|coromandel
# City not found. Skipping
# Processing Record 11 of Set 6|verkhoyansk
# City not found. Skipping
# Processing Record 12 of Set 6|kyren
# City not found. Skipping
# Processing Record 13 of Set 6|saint-raphael
# City not found. Skipping
# Processing Record 14 of Set 6|yanan
# City not found. Skipping
# Processing Record 15 of Set 6|faya
# City not found. Skipping
# Processing Record 16 of Set 6|dongzhen
# City not found. Skipping
# Processing Record 17 of Set 6|rungata
# City not found. Skipping
# Processing Record 18 of Set 6|mokhsogollokh
# City not found. Skipping
# Processing Record 19 of Set 6|kargasok
# City not found. Skipping
# Processing Record 20 of Set 6|skaerbaek
# City not found. Skipping
# Processing Record 21 of Set 6|touros
# City not found. Skipping
# Processing Record 22 of Set 6|los llanos de aridane
# City not found. Skipping
# Processing Record 23 of Set 6|hiroshima
# City not found. Skipping
# Processing Record 24 of Set 6|hualmay
# City not found. Skipping
# Processing Record 25 of Set 6|deputatskiy
# City not found. Skipping
# Processing Record 26 of Set 6|betare oya
# City not found. Skipping
# Processing Record 27 of Set 6|puerto madryn
# City not found. Skipping
# Processing Record 28 of Set 6|morondava
# City not found. Skipping
# Processing Record 29 of Set 6|balakirevo
# City not found. Skipping
# Processing Record 30 of Set 6|sol-iletsk
# City not found. Skipping
# Processing Record 31 of Set 6|santo domingo
# City not found. Skipping
# Processing Record 32 of Set 6|antalaha
# City not found. Skipping
# Processing Record 33 of Set 6|rio gallegos
# City not found. Skipping
# Processing Record 34 of Set 6|hami
# City not found. Skipping
# Processing Record 35 of Set 6|alasehir
# City not found. Skipping
# Processing Record 36 of Set 6|havre-saint-pierre
# City not found. Skipping
# Processing Record 37 of Set 6|atakpame
# City not found. Skipping
# Processing Record 38 of Set 6|kitimat
# City not found. Skipping
# Processing Record 39 of Set 6|port hedland
# City not found. Skipping
# Processing Record 40 of Set 6|mount isa
# City not found. Skipping
# Processing Record 41 of Set 6|do gonbadan
# City not found. Skipping
# Processing Record 42 of Set 6|vostok
# City not found. Skipping
# Processing Record 43 of Set 6|san juan
# City not found. Skipping
# Processing Record 44 of Set 6|tiznit
# City not found. Skipping
# Processing Record 45 of Set 6|mega
# City not found. Skipping
# Processing Record 46 of Set 6|te anau
# City not found. Skipping
# Processing Record 47 of Set 6|constitucion
# City not found. Skipping
# Processing Record 48 of Set 6|xai-xai
# City not found. Skipping
# Processing Record 49 of Set 6|kieta
# City not found. Skipping
# Processing Record 50 of Set 6|chara
# City not found. Skipping
# Processing Record 0 of Set 7|byron bay
# City not found. Skipping
# Processing Record 1 of Set 7|riaba
# City not found. Skipping
# Processing Record 2 of Set 7|kedougou
# City not found. Skipping
# Processing Record 3 of Set 7|ewa beach
# City not found. Skipping
# Processing Record 4 of Set 7|bardiyah
# City not found. Skipping
# Processing Record 5 of Set 7|rangoon
# City not found. Skipping
# Processing Record 6 of Set 7|clyde river
# City not found. Skipping
# Processing Record 7 of Set 7|isla vista
# City not found. Skipping
# Processing Record 8 of Set 7|kuche
# City not found. Skipping
# Processing Record 9 of Set 7|skovorodino
# City not found. Skipping
# Processing Record 10 of Set 7|shache
# City not found. Skipping
# Processing Record 11 of Set 7|tacna
# City not found. Skipping
# Processing Record 12 of Set 7|coihueco
# City not found. Skipping
# Processing Record 13 of Set 7|takoradi
# City not found. Skipping
# Processing Record 14 of Set 7|mabaruma
# City not found. Skipping
# Processing Record 15 of Set 7|vao
# City not found. Skipping
# Processing Record 16 of Set 7|road town
# City not found. Skipping
# Processing Record 17 of Set 7|champerico
# City not found. Skipping
# Processing Record 18 of Set 7|srandakan
# City not found. Skipping
# Processing Record 19 of Set 7|bargal
# City not found. Skipping
# Processing Record 20 of Set 7|itaguai
# City not found. Skipping
# Processing Record 21 of Set 7|beira
# City not found. Skipping
# Processing Record 22 of Set 7|port shepstone
# City not found. Skipping
# Processing Record 23 of Set 7|talaya
# City not found. Skipping
# Processing Record 24 of Set 7|nemuro
# City not found. Skipping
# Processing Record 25 of Set 7|tamale
# City not found. Skipping
# Processing Record 26 of Set 7|marystown
# City not found. Skipping
# Processing Record 27 of Set 7|thompson
# City not found. Skipping
# Processing Record 28 of Set 7|anadyr
# City not found. Skipping
# Processing Record 29 of Set 7|san cristobal
# City not found. Skipping
# Processing Record 30 of Set 7|strezhevoy
# City not found. Skipping
# Processing Record 31 of Set 7|dhidhdhoo
# City not found. Skipping
# Processing Record 32 of Set 7|athabasca
# City not found. Skipping
# Processing Record 33 of Set 7|barrow
# City not found. Skipping
# Processing Record 34 of Set 7|cacador
# City not found. Skipping
# Processing Record 35 of Set 7|alto araguaia
# City not found. Skipping
# Processing Record 36 of Set 7|turukhansk
# City not found. Skipping
# Processing Record 37 of Set 7|kamenskoye
# City not found. Skipping
# Processing Record 38 of Set 7|roma
# City not found. Skipping
# Processing Record 39 of Set 7|oranjestad
# City not found. Skipping
# Processing Record 40 of Set 7|rochegda
# City not found. Skipping
# Processing Record 41 of Set 7|svetlaya
# City not found. Skipping
# Processing Record 42 of Set 7|ullapool
# City not found. Skipping
# Processing Record 43 of Set 7|karlstad
# City not found. Skipping
# Processing Record 44 of Set 7|ekibastuz
# City not found. Skipping
# Processing Record 45 of Set 7|puerto escondido
# City not found. Skipping
# Processing Record 46 of Set 7|pangai
# City not found. Skipping
# Processing Record 47 of Set 7|ridgecrest
# City not found. Skipping
# Processing Record 48 of Set 7|ulladulla
# City not found. Skipping
# Processing Record 49 of Set 7|darhan
# City not found. Skipping
# Processing Record 50 of Set 7|tairua
# City not found. Skipping
# Processing Record 0 of Set 8|warqla
# City not found. Skipping
# Processing Record 1 of Set 8|grindavik
# City not found. Skipping
# Processing Record 2 of Set 8|bubaque
# City not found. Skipping
# Processing Record 3 of Set 8|saskylakh
# City not found. Skipping
# Processing Record 4 of Set 8|dikson
# City not found. Skipping
# Processing Record 5 of Set 8|sheregesh
# City not found. Skipping
# Processing Record 6 of Set 8|metro
# City not found. Skipping
# Processing Record 7 of Set 8|novyy urengoy
# City not found. Skipping
# Processing Record 8 of Set 8|berlevag
# City not found. Skipping
# Processing Record 9 of Set 8|beian
# City not found. Skipping
# Processing Record 10 of Set 8|avanashi
# City not found. Skipping
# Processing Record 11 of Set 8|kavieng
# City not found. Skipping
# Processing Record 12 of Set 8|flinders
# City not found. Skipping
# Processing Record 13 of Set 8|chapais
# City not found. Skipping
# Processing Record 14 of Set 8|baykit
# City not found. Skipping
# Processing Record 15 of Set 8|westport
# City not found. Skipping
# Processing Record 16 of Set 8|ngukurr
# City not found. Skipping
# Processing Record 17 of Set 8|trincomalee
# City not found. Skipping
# Processing Record 18 of Set 8|tiksi
# City not found. Skipping
# Processing Record 19 of Set 8|pochutla
# City not found. Skipping
# Processing Record 20 of Set 8|gushikawa
# City not found. Skipping
# Processing Record 21 of Set 8|belmonte
# City not found. Skipping
# Processing Record 22 of Set 8|biak
# City not found. Skipping
# Processing Record 23 of Set 8|birobidzhan
# City not found. Skipping
# Processing Record 24 of Set 8|kapit
# City not found. Skipping
# Processing Record 25 of Set 8|baherden
# City not found. Skipping
# Processing Record 26 of Set 8|manger
# City not found. Skipping
# Processing Record 27 of Set 8|severo-kurilsk
# City not found. Skipping
# Processing Record 28 of Set 8|linfen
# City not found. Skipping
# Processing Record 29 of Set 8|flin flon
# City not found. Skipping
# Processing Record 30 of Set 8|makaryev
# City not found. Skipping
# Processing Record 31 of Set 8|helong
# City not found. Skipping
# Processing Record 32 of Set 8|iranshahr
# City not found. Skipping
# Processing Record 33 of Set 8|coos bay
# City not found. Skipping
# Processing Record 34 of Set 8|verkhoshizhemye
# City not found. Skipping
# Processing Record 35 of Set 8|dillon
# City not found. Skipping
# Processing Record 36 of Set 8|sayat
# City not found. Skipping
# Processing Record 37 of Set 8|bilibino
# City not found. Skipping
# Processing Record 38 of Set 8|tual
# City not found. Skipping
# Processing Record 39 of Set 8|karakol
# City not found. Skipping
# Processing Record 40 of Set 8|velikiy ustyug
# City not found. Skipping
# Processing Record 41 of Set 8|shenzhen
# City not found. Skipping
# Processing Record 42 of Set 8|nishihara
# City not found. Skipping
# Processing Record 43 of Set 8|charters towers
# City not found. Skipping
# Processing Record 44 of Set 8|ostrovnoy
# City not found. Skipping
# Processing Record 45 of Set 8|the pas
# City not found. Skipping
# Processing Record 46 of Set 8|burnie
# City not found. Skipping
# Processing Record 47 of Set 8|rongu
# City not found. Skipping
# Processing Record 48 of Set 8|tuatapere
# City not found. Skipping
# Processing Record 49 of Set 8|camacha
# City not found. Skipping
# Processing Record 50 of Set 8|acapulco
# City not found. Skipping
# Processing Record 0 of Set 9|iskateley
# City not found. Skipping
# Processing Record 1 of Set 9|feijo
# City not found. Skipping
# Processing Record 2 of Set 9|pillaro
# City not found. Skipping
# Processing Record 3 of Set 9|sechura
# City not found. Skipping
# Processing Record 4 of Set 9|avera
# City not found. Skipping
# Processing Record 5 of Set 9|halifax
# City not found. Skipping
# Processing Record 6 of Set 9|daru
# City not found. Skipping
# Processing Record 7 of Set 9|bereda
# City not found. Skipping
# Processing Record 8 of Set 9|waingapu
# City not found. Skipping
# Processing Record 9 of Set 9|alofi
# City not found. Skipping
# Processing Record 10 of Set 9|praxedis guerrero
# City not found. Skipping
# Processing Record 11 of Set 9|loiza
# City not found. Skipping
# Processing Record 12 of Set 9|yuancheng
# City not found. Skipping
# Processing Record 13 of Set 9|qaqortoq
# City not found. Skipping
# Processing Record 14 of Set 9|biloela
# City not found. Skipping
# Processing Record 15 of Set 9|mweka
# City not found. Skipping
# Processing Record 16 of Set 9|oga
# City not found. Skipping
# Processing Record 17 of Set 9|rayevskiy
# City not found. Skipping
# Processing Record 18 of Set 9|ketchikan
# City not found. Skipping
# Processing Record 19 of Set 9|olga
# City not found. Skipping
# Processing Record 20 of Set 9|cullman
# City not found. Skipping
# Processing Record 21 of Set 9|geraldton
# City not found. Skipping
# Processing Record 22 of Set 9|siirt
# City not found. Skipping
# Processing Record 23 of Set 9|bonfim
# City not found. Skipping
# Processing Record 24 of Set 9|quelimane
# City not found. Skipping
# Processing Record 25 of Set 9|salalah
# City not found. Skipping
# Processing Record 26 of Set 9|makakilo city
# City not found. Skipping
# Processing Record 27 of Set 9|oussouye
# City not found. Skipping
# Processing Record 28 of Set 9|provideniya
# City not found. Skipping
# Processing Record 29 of Set 9|babanusah
# City not found. Skipping
# Processing Record 30 of Set 9|upington
# City not found. Skipping
# Processing Record 31 of Set 9|barra dos coqueiros
# City not found. Skipping
# Processing Record 32 of Set 9|iquitos
# City not found. Skipping
# Processing Record 33 of Set 9|nyurba
# City not found. Skipping
# Processing Record 34 of Set 9|saint-francois
# City not found. Skipping
# Processing Record 35 of Set 9|deulgaon raja
# City not found. Skipping
# Processing Record 36 of Set 9|chumikan
# City not found. Skipping
# Processing Record 37 of Set 9|mirnyy
# City not found. Skipping
# Processing Record 38 of Set 9|krasyliv
# City not found. Skipping
# Processing Record 39 of Set 9|egvekinot
# City not found. Skipping
# Processing Record 40 of Set 9|giyani
# City not found. Skipping
# Processing Record 41 of Set 9|mihijam
# City not found. Skipping
# Processing Record 42 of Set 9|kenai
# City not found. Skipping
# Processing Record 43 of Set 9|lasa
# City not found. Skipping
# Processing Record 44 of Set 9|namatanai
# City not found. Skipping
# Processing Record 45 of Set 9|harper
# City not found. Skipping
# Processing Record 46 of Set 9|port blair
# City not found. Skipping
# Processing Record 47 of Set 9|merauke
# City not found. Skipping
# Processing Record 48 of Set 9|guayaramerin
# City not found. Skipping
# Processing Record 49 of Set 9|dubbo
# City not found. Skipping
# Processing Record 50 of Set 9|watsa
# City not found. Skipping
# Processing Record 0 of Set 10|padang
# City not found. Skipping
# Processing Record 1 of Set 10|palabuhanratu
# City not found. Skipping
# Processing Record 2 of Set 10|kirovo-chepetsk
# City not found. Skipping
# Processing Record 3 of Set 10|morant bay
# City not found. Skipping
# Processing Record 4 of Set 10|neiafu
# City not found. Skipping
# Processing Record 5 of Set 10|rosetta
# City not found. Skipping
# Processing Record 6 of Set 10|pitimbu
# City not found. Skipping
# Processing Record 7 of Set 10|muika
# City not found. Skipping
# Processing Record 8 of Set 10|kampot
# City not found. Skipping
# Processing Record 9 of Set 10|lapua
# City not found. Skipping
# Processing Record 10 of Set 10|abu samrah
# City not found. Skipping
# Processing Record 11 of Set 10|praia
# City not found. Skipping
# Processing Record 12 of Set 10|kandrian
# City not found. Skipping
# Processing Record 13 of Set 10|batagay-alyta
# City not found. Skipping
# Processing Record 14 of Set 10|buala
# City not found. Skipping
# Processing Record 15 of Set 10|tura
# City not found. Skipping
# Processing Record 16 of Set 10|pisco
# City not found. Skipping
# Processing Record 17 of Set 10|vila
# City not found. Skipping
# Processing Record 18 of Set 10|wamba
# City not found. Skipping
# Processing Record 19 of Set 10|camocim
# City not found. Skipping
# Processing Record 20 of Set 10|marawi
# City not found. Skipping
# Processing Record 21 of Set 10|boyabat
# City not found. Skipping
# Processing Record 22 of Set 10|auki
# City not found. Skipping
# Processing Record 23 of Set 10|zacapoaxtla
# City not found. Skipping
# Processing Record 24 of Set 10|abu dhabi
# City not found. Skipping
# Processing Record 25 of Set 10|mullaitivu
# City not found. Skipping
# Processing Record 26 of Set 10|mittagong
# City not found. Skipping
# Processing Record 27 of Set 10|half moon bay
# City not found. Skipping
# Processing Record 28 of Set 10|honiara
# City not found. Skipping
# Processing Record 29 of Set 10|northam
# City not found. Skipping
# Processing Record 30 of Set 10|bontang
# City not found. Skipping
# Processing Record 31 of Set 10|neuquen
# City not found. Skipping
# Processing Record 32 of Set 10|phan thiet
# City not found. Skipping
# Processing Record 33 of Set 10|goderich
# City not found. Skipping
# Processing Record 34 of Set 10|victor harbor
# City not found. Skipping
# Processing Record 35 of Set 10|houlton
# City not found. Skipping
# Processing Record 36 of Set 10|kralendijk
# City not found. Skipping
# Processing Record 37 of Set 10|karasjok
# City not found. Skipping
# Processing Record 38 of Set 10|bolshegrivskoye
# City not found. Skipping
# Processing Record 39 of Set 10|cockburn town
# City not found. Skipping
# Processing Record 40 of Set 10|sur
# City not found. Skipping
# Processing Record 41 of Set 10|vidim
# City not found. Skipping
# Processing Record 42 of Set 10|soller
# City not found. Skipping
# Processing Record 43 of Set 10|ulaangom
# City not found. Skipping
# Processing Record 44 of Set 10|alma
# City not found. Skipping
# Processing Record 45 of Set 10|homer
# City not found. Skipping
# Processing Record 46 of Set 10|rawson
# City not found. Skipping
# Processing Record 47 of Set 10|tazovskiy
# City not found. Skipping
# Processing Record 48 of Set 10|hensall
# City not found. Skipping
# Processing Record 49 of Set 10|ikungi
# City not found. Skipping
# Processing Record 50 of Set 10|fandriana
# City not found. Skipping
# Processing Record 0 of Set 11|camargo
# City not found. Skipping
# Processing Record 1 of Set 11|port hueneme
# City not found. Skipping
# Processing Record 2 of Set 11|port-gentil
# City not found. Skipping
# Processing Record 3 of Set 11|temiscaming
# City not found. Skipping
# Processing Record 4 of Set 11|bjornevatn
# City not found. Skipping
# Processing Record 5 of Set 11|macaboboni
# City not found. Skipping
# Processing Record 6 of Set 11|paramithia
# City not found. Skipping
# Processing Record 7 of Set 11|mushabani
# City not found. Skipping
# Processing Record 8 of Set 11|morehead
# City not found. Skipping
# Processing Record 9 of Set 11|porto walter
# City not found. Skipping
# Processing Record 10 of Set 11|hede
# City not found. Skipping
# Processing Record 11 of Set 11|hadejia
# City not found. Skipping
# Processing Record 12 of Set 11|steamboat springs
# City not found. Skipping
# Processing Record 13 of Set 11|ambovombe
# City not found. Skipping
# Processing Record 14 of Set 11|gold coast
# City not found. Skipping
# Processing Record 15 of Set 11|anloga
# City not found. Skipping
# Processing Record 16 of Set 11|matara
# City not found. Skipping
# Processing Record 17 of Set 11|talas
# City not found. Skipping
# Processing Record 18 of Set 11|hearst
# City not found. Skipping
# Processing Record 19 of Set 11|bahar
# City not found. Skipping
# Processing Record 20 of Set 11|pontes e lacerda
# City not found. Skipping
# Processing Record 21 of Set 11|bilma
# City not found. Skipping
# Processing Record 22 of Set 11|kropotkin
# City not found. Skipping
# Processing Record 23 of Set 11|wellington
# City not found. Skipping
# Processing Record 24 of Set 11|muzhi
# City not found. Skipping
# Processing Record 25 of Set 11|poya
# City not found. Skipping
# Processing Record 26 of Set 11|aklavik
# City not found. Skipping
# Processing Record 27 of Set 11|illapel
# City not found. Skipping
# Processing Record 28 of Set 11|teluk nibung
# City not found. Skipping
# Processing Record 29 of Set 11|tarrafal
# City not found. Skipping
# Processing Record 30 of Set 11|jimeta
# City not found. Skipping
# Processing Record 31 of Set 11|bodoc
# City not found. Skipping
# Processing Record 32 of Set 11|shingu
# City not found. Skipping
# Processing Record 33 of Set 11|sayyan
# City not found. Skipping
# Processing Record 34 of Set 11|marcona
# City not found. Skipping
# Processing Record 35 of Set 11|srostki
# City not found. Skipping
# Processing Record 36 of Set 11|friedeburg
# City not found. Skipping
# Processing Record 37 of Set 11|marsa matruh
# City not found. Skipping
# Processing Record 38 of Set 11|mahadday weyne
# City not found. Skipping
# Processing Record 39 of Set 11|krasnyy chikoy
# City not found. Skipping
# Processing Record 40 of Set 11|hudson bay
# City not found. Skipping
# Processing Record 41 of Set 11|havoysund
# City not found. Skipping
# Processing Record 42 of Set 11|lesogorsk
# City not found. Skipping
# Processing Record 43 of Set 11|sentyabrskiy
# City not found. Skipping
# Processing Record 44 of Set 11|liverpool
# City not found. Skipping
# Processing Record 45 of Set 11|nome
# City not found. Skipping
# Processing Record 46 of Set 11|haysville
# City not found. Skipping
# Processing Record 47 of Set 11|kushmurun
# City not found. Skipping
# Processing Record 48 of Set 11|aitape
# City not found. Skipping
# Processing Record 49 of Set 11|beoumi
# City not found. Skipping
# Processing Record 50 of Set 11|one hundred mile house
# City not found. Skipping
# Processing Record 0 of Set 12|grand forks
# City not found. Skipping
# Processing Record 1 of Set 12|coquimbo
# City not found. Skipping
# Processing Record 2 of Set 12|petrozavodsk
# City not found. Skipping
# Processing Record 3 of Set 12|dongsheng
# City not found. Skipping
# Processing Record 4 of Set 12|samagaltay
# City not found. Skipping
# Processing Record 5 of Set 12|cap malheureux
# City not found. Skipping
# Processing Record 6 of Set 12|pangody
# City not found. Skipping
# Processing Record 7 of Set 12|yenagoa
# City not found. Skipping
# Processing Record 8 of Set 12|hovd
# City not found. Skipping
# Processing Record 9 of Set 12|rafai
# City not found. Skipping
# Processing Record 10 of Set 12|port macquarie
# City not found. Skipping
# Processing Record 11 of Set 12|linqiong
# City not found. Skipping
# Processing Record 12 of Set 12|kudahuvadhoo
# City not found. Skipping
# Processing Record 13 of Set 12|vangaindrano
# City not found. Skipping
# Processing Record 14 of Set 12|ulaanbaatar
# City not found. Skipping
# Processing Record 15 of Set 12|batemans bay
# City not found. Skipping
# Processing Record 16 of Set 12|alice springs
# City not found. Skipping
# Processing Record 17 of Set 12|el alto
# City not found. Skipping
# Processing Record 18 of Set 12|hutchinson
# City not found. Skipping
# Processing Record 19 of Set 12|halalo
# City not found. Skipping
# Processing Record 20 of Set 12|chicama
# City not found. Skipping
# Processing Record 21 of Set 12|hendek
# City not found. Skipping
# Processing Record 22 of Set 12|pyshchug
# City not found. Skipping
# Processing Record 23 of Set 12|lakatoro
# City not found. Skipping
# Processing Record 24 of Set 12|klaksvik
# City not found. Skipping
# Processing Record 25 of Set 12|zhuozhou
# City not found. Skipping
# Processing Record 26 of Set 12|malibu
# City not found. Skipping
# Processing Record 27 of Set 12|luganville
# City not found. Skipping
# Processing Record 28 of Set 12|gat
# City not found. Skipping
# Processing Record 29 of Set 12|morogoro
# City not found. Skipping
# Processing Record 30 of Set 12|college
# City not found. Skipping
# Processing Record 31 of Set 12|port lavaca
# City not found. Skipping
# Processing Record 32 of Set 12|constantine
# City not found. Skipping
# Processing Record 33 of Set 12|iqaluit
# City not found. Skipping
# Processing Record 34 of Set 12|aginskoye
# City not found. Skipping
# Processing Record 35 of Set 12|alugan
# City not found. Skipping
# Processing Record 36 of Set 12|nchelenge
# City not found. Skipping
# Processing Record 37 of Set 12|kiama
# City not found. Skipping
# Processing Record 38 of Set 12|samoded
# City not found. Skipping
# Processing Record 39 of Set 12|tsnori
# City not found. Skipping
# Processing Record 40 of Set 12|jardim
# City not found. Skipping
# Processing Record 41 of Set 12|minna
# City not found. Skipping
# Processing Record 42 of Set 12|cavaillon
# City not found. Skipping
# Processing Record 43 of Set 12|tezu
# City not found. Skipping
# Processing Record 44 of Set 12|vila franca do campo
# City not found. Skipping
# Processing Record 45 of Set 12|kendari
# City not found. Skipping
# Processing Record 46 of Set 12|walvis bay
# City not found. Skipping
# Processing Record 47 of Set 12|dunedin
# City not found. Skipping
# Processing Record 48 of Set 12|tougue
# City not found. Skipping
# Processing Record 49 of Set 12|saint-augustin
# City not found. Skipping
# Processing Record 50 of Set 12|gamba
# City not found. Skipping
# Processing Record 0 of Set 13|rancho palos verdes
# City not found. Skipping
# Processing Record 1 of Set 13|altamont
# City not found. Skipping
# Processing Record 2 of Set 13|bud
# City not found. Skipping
# Processing Record 3 of Set 13|san jose
# City not found. Skipping
# Processing Record 4 of Set 13|ola
# City not found. Skipping
# Processing Record 5 of Set 13|nanning
# City not found. Skipping
# Processing Record 6 of Set 13|worland
# City not found. Skipping
# Processing Record 7 of Set 13|umm lajj
# City not found. Skipping
# Data Retrieval Complete

# %%
weather_df.count()
# Out:
# City          620
# Lat           620
# Lng           620
# Country       620
# Date          620
# Max Temp      620
# Humidity      620
# Cloudiness    620
# Windspeed     620
# dtype: int64

# %%
weather_df.dtypes
# Out:
# City          object
# Lat           object
# Lng           object
# Country       object
# Date          object
# Max Temp      object
# Humidity      object
# Cloudiness    object
# Windspeed     object
# dtype: object

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df.head()
# Out:
#         City Lat Lng Country Date Max Temp Humidity Cloudiness Windspeed
# 0     kodiak
# 1      kapaa
# 2    ushuaia
# 3  busselton
# 4      vaini

# %%
#Convert values to numeric and save the csv file
pd.to_numeric(weather_df['Lat']).astype(float)
pd.to_numeric(weather_df['Lng']).astype(float)
pd.to_numeric(weather_df["Max Temp"]).astype(float)
pd.to_numeric(weather_df["Humidity"]).astype(float)
pd.to_numeric(weather_df["Cloudiness"]).astype(float)
pd.to_numeric(weather_df["Windspeed"]).astype(float)

weather_df.to_csv("output_data/WeatherDataFrame.csv", index=False, header=True)

weather_df.head()
# Out:
#         City Lat Lng Country Date Max Temp Humidity Cloudiness Windspeed
# 0     kodiak
# 1      kapaa
# 2    ushuaia
# 3  busselton
# 4      vaini

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Max Temp'], color='blue', alpha=0.5, marker="o")
plt.title(f'Latitude vs. Max Temperature {time.strftime("%m/%d/%Y")}')
plt.ylabel('Temperature (F)')
plt.xlable('Latitude')
plt.grid(True)
plt.savefig("Output/Max Temperature.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Humidity'], color='red', marker="^")
plt.title(f'Latitude vs. Humidity {time.strftime("%m/%d/%Y")}')
plt.ylabel('Humidity')
plt.xlable('Latitude')
plt.grid(True)
plt.savefig("Output/Humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Cloudiness'], color='yellow', marker="o")
plt.title(f'Latitude vs. Cloudiness {time.strftime("%m/%d/%Y")}')
plt.ylabel('Cloudiness')
plt.xlable('Latitude')
plt.grid(True)
plt.savefig("Output/Cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df['Lat'], weather_df['Windspeed'], color='green', marker="^")
plt.title(f'Latitude vs. Windspeed {time.strftime("%m/%d/%Y")}')
plt.ylabel('Wind Speed (mph)')
plt.xlable('Latitude')
plt.grid(True)
plt.savefig("Output/Windspeed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hem = weather_df.loc[pd.to_numeric(weather_df['Lat']).astype(float) > 0, :]
southern_hem = weather_df.loc[pd.to_numeric(weather_df['Lat']).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.numeric(northern_hem['Lat']).astype(float)
y_values = pd.numeric(northern_hem['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_value, "r-")
plt.annotate(line_eq, (7,10)fontsize=12, color="orange")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("There's an negative correlation")
print("The temperature decreases as the latitude increases")
plt.savefig("output_data/NHemishere Tempvslat.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.numeric(southern_hem['Lat']).astype(float)
y_values = pd.numeric(southern_hem['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_value, "r-")
plt.annotate(line_eq, (7,10)fontsize=12, color="orange")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("There's an positive correlation")
print("The temperature increases as the latitude decreases")
plt.savefig("output_data/SHemishere Tempvslat.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.numeric(northern_hem['Lat']).astype(float)
y_values = pd.numeric(northern_hem['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_value, "r-")
plt.annotate(line_eq, (7,10)fontsize=12, color="orange")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Northern Hemisphere - Humidity vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("There's no correlation between humidity and latitude")
plt.savefig("output_data/NHemishere Humidvslat.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.numeric(southern_hem['Lat']).astype(float)
y_values = pd.numeric(southern_hem['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_value, "r-")
plt.annotate(line_eq, (7,10)fontsize=12, color="orange")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Southern Hemisphere - Humidity vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("There's no correlation between the humidity and latitude")

plt.savefig("output_data/SHemishere Humidvslat.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.numeric(northern_hem['Lat']).astype(float)
y_values = pd.numeric(northern_hem['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_value, "r-")
plt.annotate(line_eq, (7,10)fontsize=12, color="orange")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("There's no correlation between cloudiness and latitude")
plt.savefig("output_data/NHemishere cloudvslat.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.numeric(southern_hem['Lat']).astype(float)
y_values = pd.numeric(southern_hem['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_value, "r-")
plt.annotate(line_eq, (7,10)fontsize=12, color="orange")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("There's no correlation between the cloudiness and latitude")

plt.savefig("output_data/SHemishere cloudvslat.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.numeric(northern_hem['Lat']).astype(float)
y_values = pd.numeric(northern_hem['Windspeed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_value, "r-")
plt.annotate(line_eq, (7,10)fontsize=12, color="orange")
plt.xlabel('Latitude')
plt.ylabel('Windspeed')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("There's no correlation between windspeed and latitude")
plt.savefig("output_data/NHemishere windvslat.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.numeric(southern_hem['Lat']).astype(float)
y_values = pd.numeric(southern_hem['Windspeed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_value, "r-")
plt.annotate(line_eq, (7,10)fontsize=12, color="orange")
plt.xlabel('Latitude')
plt.ylabel('Windspeed')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("There's no correlation between the cloudiness and latitude")

plt.savefig("output_data/SHemishere windvslat.png")
plt.show()
